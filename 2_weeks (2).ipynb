# %%
import pandas as pd
import numpy as np
stocklist = pd.read_csv('selected_stocks.csv', index_col = 0)
stocklist = stocklist['stock_name']

# %%
df = pd.DataFrame(columns= ['stockname', 'avg_profit', 'num_trades'])

for stockname in stocklist:
    df_all = pd.read_csv(stockname+".csv", names=('Dates', 'stockVWAP', 'futureVWAP', 'bidPrice', 'askPrice', 'total_value', 'total_size'))
    df_train = df_all[:60000]
    df_train_for_10min = df_train[df_train.index%10 == 0]
    df_train_for_10min = df_train_for_10min.reset_index(drop = True)
    df_final = df_train_for_10min
    
    spread = df_final['askPrice'].max() - df_final['bidPrice'].max()
    
    data = np.array([])
    for i in range(555):
        data = np.append(data, df_final.iloc[i,1] ) 
    for i in range(555, 6000):
        data = np.append(data, np.mean(df_final.iloc[i-224:i+1])) 
        
    df_new = pd.DataFrame(data)
    
    no_of_trades = 0
    dev_sum = 0
        
    for i in range(6000):
        dev = df_final.loc[i,'stockVWAP'] - 0.2 - spread - df_new.loc[i,0]
        if dev > 0:
            no_of_trades = no_of_trades + 1
            dev_sum = dev + dev_sum
    
    if no_of_trades != 0:
        dev_mean = dev_sum/no_of_trades 
        Total_Profit = dev_sum
    
    if no_of_trades == 0:
        Total_Profit = 0
        dev_mean = 0

    s = pd.Series([stockname, dev_mean, no_of_trades],index= ['stockname', 'avg_profit', 'num_trades'])
    df = df.append(s,ignore_index=True)
    
    print(stockname + ":" + str(dev_mean) + ":" + str(no_of_trades))
df.to_csv("profits_5d.csv")
# Out:
# JPASSOCIAT:5.016536984719652:2735
# GMRINFRA:2.7918409757777165:3425
# SUZLON:6.883051017613518:2873
# IBREALEST:90.91997023356572:2837
# RELCAPITAL:144.92948345898628:3516
# DLF:32.61288502715453:3589
# IDFC:2.7357655771444493:2182
# SOUTHBANK:4.409493292890723:2574
# IDFCBANK:2.344608232483461:459
# BANKBARODA:8.316493094203663:1804
# MANAPPURAM:39.17742470415173:2658
# HINDALCO:16.73151188665617:3133
# TATASTEEL:52.06496797667124:3035
# JINDALSTEL:32.788274253795116:3586
# RCOM:4.026074559230177:1297
# HDIL:16.799887113085397:3011
# L&TFH:30.268265901712077:3578
# NMDC:1.9652850131470578:393
# ADANIPOWER:3.2038838759355084:806
# HCC:21.135023146953866:1786
# ICICIBANK:16.6848793517644:3304
# SUNTV:158.4815156578039:3428
# RELINFRA:44.93776311605018:1981
# PNB:11.369228308296139:3159
# JSWSTEEL:20.017649673694308:2234
# APOLLOTYRE:58.0353648907118:2839
# MOTHERSUMI:56.18465478774993:2648
# RECLTD:33.246666216867055:3586
# ONGC:3.297770898220124:245
# RPOWER:1.9675235605333872:1823
# IDEA:27.766603064276243:1052
# JSWENERGY:2.791268412063698:2762
# IFCI:1.1648724688722474:1011
# DHFL:105.74231243453282:3574
# TV18BRDCST:3.772660131967565:1900
# CANBK:36.955147792408056:3526
# BANKINDIA:20.635953431982806:3537
# ORIENTBANK:21.115702808144714:3404
# PFC:13.786472889681583:1748
# EXIDEIND:18.289042635093452:3213
# NCC:5.468622403135924:2759
# KTKBANK:35.898632960696425:3159
# BHARATFIN:88.88669539300982:1635
# M&MFIN:52.90218692638498:3360
# GRASIM:136.43261177974784:3627
# NATIONALUM:35.61443305073097:1848
# AXISBANK:25.755550609751833:3291
# UNIONBANK:10.560236623768851:2593
# AUROPHARMA:54.0374583359559:1046
# INFIBEAM:592.508277142357:2039
# BEL:31.627614549344827:750
# FORTIS:83.46967900529711:2170
# ALBK:6.062768822526515:2233
# HINDPETRO:31.838253011693045:1149
# MRPL:43.741520352224946:3309
# TATAPOWER:3.419720806111574:2049
# PTC:11.653210041690922:3574
# NHPC:1.466580904387469:2401
# NTPC:1.813400093076273:476
# IOC:30.388050245330973:3191
# BPCL:26.655934680711336:1501
# INFY:43.44851080145278:1988
# RELIANCE:340.9972416561469:3285
# DISHTV:11.259378166856196:1861
# JUSTDIAL:123.88429382278545:2263
# ITC:18.664515696447967:3611
# SYNDIBANK:6.119773883340661:3011
# TATAMTRDVR:6.326318062937044:226
# CESC:103.20325892010852:3631
# GAIL:35.89466556870551:780
# JISLJALEQS:6.363577091938439:2890
# COALINDIA:11.297791911090206:749
# PCJEWELLER:63.40279030169544:2085
# ANDHRABANK:5.4961459121954315:2976
# CGPOWER:80.90075178927924:4311
# POWERGRID:8.31971695637343:2565
# GSFC:45.450965162911054:3239
# AMBUJACEM:16.593721962087457:3266
# ADANIPORTS:44.148620021607385:3549
# SREINFRA:40.331422422359054:3121
# EQUITAS:94.03641833519353:1687
# IRB:13.422664936637512:1916
# DCBBANK:49.51504452483291:3458
# YESBANK:136.9091809501966:3599
# TVSMOTOR:101.2811348079954:3573
# RDEL:22.759769376578813:2663
# KOTAKBANK:132.4826136810763:3604
# SRTRANSFIN:51.119124864691585:3252
# UJJIVAN:190.5674090706956:2077
# PETRONET:37.063826345531915:2676
# BALRAMCHIN:52.48801968830461:3060
# BHARTIARTL:30.031975778406427:3220
# HDFCBANK:245.28724031420268:2709
